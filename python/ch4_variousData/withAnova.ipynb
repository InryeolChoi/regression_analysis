# %% [markdown]
# # 분산분석
# * 분산분석을 회귀분석의 응용으로 보는 것이 주요 목표
#
# * 분산분석의 메인 테마 : 집단 간 비교. 근데 왠 회귀?
#
# * 회귀분석의 검정 = 분산분석의 집단 간 비교로 해석될 수 있음.

# %% [markdown]
# # 일원 분산분석
# 일원 분산분석(One-Way ANOVA)은 하나의 범주형 독립 변수를 사용하여 여러 그룹 간의 평균 차이를 분석하는 것이다.
#
# 예를 들어, 일원 분산분석은 다음과 같은 모형으로 표현될 수 있다:
# $$
# Y_{ij} = \mu + \tau_i + \epsilon_{ij}
# $$
#
# 여기서,
#
# - $Y_{ij}$는 $i$번째 그룹의 $j$번째 관측치를 의미하며,
#
# - $\mu$는 전체 평균,
#
# - $\tau_i$는 $i$번째 그룹의 효과 (각 그룹의 평균에서 전체 평균을 뺀 값),
#
# - $\epsilon_{ij}$는 오차항을 의미한다.

# %% [markdown]
# ## 회귀분석으로 변신
# 이제 이 식을 회귀분석의 형태로 변환해보자.
#
# * 그룹 효과 $\tau_i$는 더미 변수를 사용하여 회귀분석 모형에서 표현될 수 있다.
# * 만약 그룹이 $k$개라면, $k-1$개의 더미 변수를 생성하여 회귀분석 모형에 포함시킬 수 있다.
#
# * 예를 들어, $k = 3$인 경우, 다음과 같은 회귀분석 모형을 세울 수 있다:
#
# $$
# Y = \beta_0 + \beta_1 D_1 + \beta_2 D_2 + \epsilon
# $$
#
# 여기서,
#
# - $Y$는 종속 변수,
# - $\beta_0$는 기준 그룹(즉, $D_1 = 0$ 및 $D_2 = 0$일 때)의 평균을 의미하며,
# - $\beta_1$, $\beta_2$는 각각 그룹 1과 그룹 2의 효과를 나타내는 회귀 계수이다.
# - $D_1$, $D_2$는 더미 변수로, 각 그룹에 해당하면 1, 그렇지 않으면 0의 값을 가진다.
# - $\epsilon$는 오차항이다.

# %% [markdown]
# ## 더미변수의 해석
# 따라서, 회귀분석의 모형은 각 그룹의 평균을 표현하는 일원 분산분석의 모형과 동일한 의미를 가진다.
#
# 이러한 변환은 다음과 같은 더미 변수를 사용하여 이루어진다:
#
#
#
# $$
# \tau_i =
# \begin{cases}
# \beta_1 & \text{if group 1} \\
# \beta_2 & \text{if group 2} \\
# 0 & \text{if reference group}
# \end{cases}
# $$

# %% [markdown]
# # 이원 분산분석
# 이원 분산분석은 두 개의 독립변수 (요인)가 종속변수에 미치는 영향을 동시에 분석하는 방법이다.
#
# 이원 분산분석의 기본 모형은 다음과 같다:
#
# $$
# Y_{ijk} = \mu + \alpha_i + \beta_j + (\alpha\beta)_{ij} + \epsilon_{ijk}
# $$
#
# 여기서,
#
# - $Y_{ijk}$는 $i$번째 수준의 첫 번째 요인, $j$번째 수준의 두 번째 요인, 그리고 $k$번째 관측치에서의 종속변수 값이다.
#
# - $\mu$는 전체 평균을 의미한다.
#
# - $\alpha_i$는 첫 번째 요인($X_1$)의 $i$번째 수준의 효과를 나타낸다.
#
# - $\beta_j$는 두 번째 요인($X_2$)의 $j$번째 수준의 효과를 나타낸다.
#
# - $(\alpha\beta)_{ij}$는 두 요인의 상호작용 효과를 나타내며, 이는 두 요인의 조합에 따른 추가적인 변화를 의미한다.
#
# - $\epsilon_{ijk}$는 오차항이다.

# %% [markdown]
# ## 회귀분석으로 변신
#
# 이를 회귀분석 모형으로 바꿔보자.
#
#
# $$
# Y = \beta_0 + \beta_1 X_1 + \beta_2 X_2 + \beta_3 (X_1 \times X_2) + \epsilon
# $$
#
#
# 여기서,
#
# - $Y$는 종속변수이다.
#
# - $\beta_0$는 전체 평균, 즉 기준 수준에서의 예측값을 의미한다. ($=\mu$)
#
# - $\beta_1$, $\beta_2$는 각각 독립변수 $X_1$, $X_2$의 효과를 나타내는 회귀계수이다.
#
# - $\beta_3$는 $X_1$과 $X_2$의 상호작용 효과를 나타내는 회귀계수로, $(X_1 \times X_2)$는 두 독립변수의 곱으로 계산된다.
#
# - $\epsilon$는 오차항이다.
#
#
# ## 용어의 정리
# - 회귀분석에서의 독립변수 = 분산분석의 요인
#
# - 회귀분석에서의 회귀계수 = 분산분석의 효과

# %% [markdown]
# ## 더미변수의 해석
#
# 회귀분석에서 $X_1$과 $X_2$는 요인들의 더미 변수로 표현되며, 이들 간의 상호작용 $(X_1 \times X_2)$ 항을 통해 상호작용 효과를 모형에 포함시킬 수 있다.
#
# 이는 이원 분산분석 모형에서의 상호작용 효과 $(\alpha\beta)_{ij}$를 회귀분석에서 표현한 것이다.
#
# 따라서, 이원 분산분석 모형은 회귀분석 모형으로 전환될 수 있으며, 두 모형 모두 두 요인 간의 상호작용을 포함하여 종속변수에 미치는 영향을 분석한다.

# %% [markdown]
# # 공분산분석
# 공분산분석(ANCOVA)은 분산분석(ANOVA)과 회귀분석을 결합한 기법.
#
# 종속변수에 영향을 미칠 수 있는 공변량(covariate)을 통제하면서 독립변수의 효과를 평가한다.
#
# 공분산분석의 기본 모형은 다음과 같다:
#
# $$
# Y_{ij} = \mu + \alpha_i + \beta X + \epsilon_{ij}
# $$
#
# 여기서,
#
# - $Y_{ij}$는 $i$번째 수준의 독립변수에서 $j$번째 관측치의 종속변수 값이다.
#
# - $\mu$는 전체 평균을 의미한다.
#
# - $\alpha_i$는 범주형 독립변수(요인)의 $i$번째 수준의 효과를 나타낸다.
#
# - $\beta X$는 공변량 $X$의 효과를 나타내며, $\beta$는 공변량의 회귀계수이다.
#
# - $\epsilon_{ij}$는 오차항이다.

# %% [markdown]
# ## 회귀분석으로 변신
# 이를 회귀분석으로 바꿔보자.
#
# $$
# Y = \beta_0 + \beta_1 X_1 + \beta_2 X + \epsilon
# $$
#
# 여기서,
#
# - $Y$는 종속변수이다.
#
# - $\beta_0$는 전체 평균을 나타내며, 기준 수준에서의 예측값이다.
#
# - $\beta_1 X_1$는 요인의 수준에 따른 효과를 나타내며, $X_1$은 독립변수를 더미 변수로 표현한 것이다.
#
# - $\beta_2 X$는 공변량 $X$의 효과를 나타내며, $\beta_2$는 공변량의 회귀계수이다.
#
# - $\epsilon$는 오차항이다.

# %% [markdown]
# ## 종합적인 해석
# 공분산분석에서는 요인의 효과를 추정할 때, 공변량 $X$가 종속변수 $Y$에 미치는 영향을 통제한다.
#
# 회귀분석 모형으로 표현하면, 공변량의 회귀계수 $\beta_2$를 포함하여 요인의 효과 $\beta_1$을 분석할 수 있다.
#
# 따라서 공분산분석 모형은 회귀분석 모형으로 전환될 수 있으며, 이를 통해 독립변수의 효과를 보다 정확하게 평가하면서 공변량의 영향을 통제할 수 있다.

# %% [markdown]
# # 선형혼합모형
#
# 분산분석과 회귀분석의 개념을 확장하면 선형혼합모형(Linear Mixed Model)으로 이어진다.
#
# 선형혼합모형은 고정 효과(fixed effects)와 더불어 무작위 효과(random effects)를 포함하는 모형이다.
#
# 이 모형은 관측치들이 서로 독립적이지 않은 경우, 예를 들어 그룹 내의 데이터가 상관되어 있는 경우에 사용된다.
#
# 선형혼합모형은 다음과 같이 표현될 수 있다:
#
# $$
# Y_{ij} = \beta_0 + \beta_1 X_{ij} + u_j + \epsilon_{ij}
# $$
#
# 여기서
# - $u_j$는 그룹 $j$의 무작위 효과를 나타내며, 이는 그룹 간의 차이를 설명한다.
#
# - $\epsilon_{ij}$는 오차항이다.
#
# 이를 통해 선형혼합모형은 데이터의 군집 구조를 고려하여 보다 정확한 추정을 가능하게 한다.

# %% [markdown]
# # 예시 코드

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_regression
import statsmodels.api as sm
from statsmodels.regression.mixed_linear_model import MixedLM

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ## 일원 분산분석

# %%
np.random.seed(42)

# 일원 분산분석 데이터 생성
n_samples = 100
cylinders = np.random.choice([4, 6, 8], n_samples)
weight = np.random.normal(3000, 500, n_samples)
mpg = 20 - 0.01 * weight + np.random.normal(0, 2, n_samples) + (cylinders - 4) * 2

df_anova = pd.DataFrame({
    'mpg': mpg,
    'cylinders': cylinders,
    'weight': weight
})

# %%
# 일원 분산분석
model_anova = ols('mpg ~ C(cylinders)', data=df_anova).fit()
anova_table = sm.stats.anova_lm(model_anova, typ=2)
print("One-Way ANOVA Results:")
print(anova_table)

# 시각화
plt.figure(figsize=(10, 6))
sns.boxplot(x='cylinders', y='mpg', data=df_anova)
plt.title('One-Way ANOVA: Effect of Cylinders on MPG')
plt.show()
# Out:
# One-Way ANOVA Results:
#                    sum_sq    df          F        PR(>F)
# C(cylinders)  1360.203270   2.0  24.191707  2.995424e-09
# Residual      2726.961744  97.0        NaN           NaN

# %% [markdown]
# ## 이원 분산분석

# %%
# 이원 분산분석을 위한 데이터 생성
df_two_way = df_anova.copy()
df_two_way['gear'] = np.random.choice(['3', '4', '5'], n_samples)

# %%
# 이원 분산분석
model_two_way = ols('mpg ~ C(cylinders) * C(gear)', data=df_two_way).fit()
anova_two_way_table = sm.stats.anova_lm(model_two_way, typ=2)
print("Two-Way ANOVA Results:")
print(anova_two_way_table)

# 시각화
plt.figure(figsize=(10, 6))
sns.boxplot(x='cylinders', y='mpg', hue='gear', data=df_two_way)
plt.title('Two-Way ANOVA: Effect of Cylinders and Gear on MPG')
plt.show()
# Out:
# Two-Way ANOVA Results:
#                            sum_sq    df          F        PR(>F)
# C(cylinders)          1234.289762   2.0  21.610200  2.092379e-08
# C(gear)                 66.340192   2.0   1.161498  3.176134e-01
# C(cylinders):C(gear)    61.840179   4.0   0.541355  7.057349e-01
# Residual              2598.781374  91.0        NaN           NaN

# %% [markdown]
# ## 공분산분석

# %%
# 공분산분석을 위한 데이터 생성
df_ancova = df_anova.copy()
df_ancova['horsepower'] = np.random.normal(100, 20, n_samples)

# %%
# 공분산분석
model_ancova = ols('mpg ~ C(cylinders) + horsepower', data=df_ancova).fit()
ancova_table = sm.stats.anova_lm(model_ancova, typ=2)
print("ANCOVA Results:")
print(ancova_table)

# 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x='horsepower', y='mpg', hue='cylinders', data=df_ancova)
sns.regplot(x='horsepower', y='mpg', data=df_ancova, scatter=False, color='black')
plt.title('ANCOVA: Effect of Cylinders and Horsepower on MPG')
plt.show()
# Out:
# ANCOVA Results:
#                    sum_sq    df          F        PR(>F)
# C(cylinders)  1377.429841   2.0  24.399673  2.705343e-09
# horsepower      17.227396   1.0   0.610329  4.365862e-01
# Residual      2709.734348  96.0        NaN           NaN

# %% [markdown]
# ## 선형혼합모형

# %%
# 선형 혼합 모형을 위한 새로운 데이터 생성
n_groups = 10
n_per_group = 10
group = np.repeat(np.arange(n_groups), n_per_group)
subgroup = np.tile(np.arange(2), n_groups * (n_per_group // 2))
response = 50 + 2 * group + 3 * subgroup + np.random.normal(0, 2, n_groups * n_per_group)

df_mixed = pd.DataFrame({
    'response': response,
    'group': group,
    'subgroup': subgroup,
    'id': np.arange(n_groups * n_per_group)
})

# %%
# 선형 혼합 모형
model_mixed = MixedLM.from_formula('response ~ subgroup', groups=df_mixed['group'], data=df_mixed)
result_mixed = model_mixed.fit()
print("Linear Mixed Model Results:")
print(result_mixed.summary())

# 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x='subgroup', y='response', hue='group', data=df_mixed)
plt.title('Response vs. Subgroup by Group')
plt.show()

# 그룹별 평균 반응 값 시각화
group_means = df_mixed.groupby(['group', 'subgroup'])['response'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(x='subgroup', y='response', hue='group', data=group_means, marker='o')
plt.title('Mean Response by Subgroup and Group')
plt.show()
# Out:
# Linear Mixed Model Results:
#          Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: response
# No. Observations: 100     Method:             REML
# No. Groups:       10      Scale:              4.6943
# Min. group size:  10      Log-Likelihood:     -238.2060
# Max. group size:  10      Converged:          Yes
# Mean group size:  10.0
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept    59.472    1.897 31.355 0.000 55.755 63.190
# subgroup      2.780    0.433  6.416 0.000  1.931  3.629
# Group Var    35.038    8.107
# ...
